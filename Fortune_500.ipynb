# %%
url = 'https://content.fortune.com/wp-json/irving/v1/data/franchise-search-results?list_id=2814606&token=Zm9ydHVuZTpCcHNyZmtNZCN5SndjWkkhNHFqMndEOTM='
import requests
resp = requests.get(url)
resp.json()[1]
# Out:
# {'key': 'items',
#  'items': [{'fields': [{'key': 'rank', 'value': '102'},
#     {'key': 'f500_revenues', 'value': '32293.6'},
#     {'key': 'revchange', 'value': '10.9'},
#     {'key': 'f500_profits', 'value': '1268'},
#     {'key': 'prftchange', 'value': '61.9'},
#     {'key': 'assets', 'value': '290318'},
#     {'key': 'f500_mktval', 'value': ''},
#     {'key': 'rankchange1000', 'value': '9'},
#     {'key': 'f500_ employees', 'value': '5964'},
#     {'key': 'rankchange', 'value': '9'},
#     {'key': 'name', 'value': 'Northwestern Mutual'},
#     {'key': 'sector', 'value': 'Financials'},
#     {'key': 'f500_industry', 'value': 'Insurance: Life, Health (Mutual)'},
#     {'key': 'hqcity', 'value': 'Milwaukee'},
#     {'key': 'hqstate', 'value': 'WI'},
#     {'key': 'rankgain', 'value': 'yes'},
#     {'key': 'rankdrop', 'value': 'no'},
#     {'key': 'newcomer', 'value': 'no'},
#     {'key': 'profitable', 'value': 'yes'},
#     {'key': 'ceofounder', 'value': 'no'},
# ...
